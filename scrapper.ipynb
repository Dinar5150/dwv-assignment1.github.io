# %%
# !pip install requests beautifulsoup4
# Out:
# Requirement already satisfied: requests in c:\users\dinar\appdata\local\programs\python\python310\lib\site-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in c:\users\dinar\appdata\local\programs\python\python310\lib\site-packages (4.13.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dinar\appdata\local\programs\python\python310\lib\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dinar\appdata\local\programs\python\python310\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dinar\appdata\local\programs\python\python310\lib\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dinar\appdata\local\programs\python\python310\lib\site-packages (from requests) (2024.12.14)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dinar\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\dinar\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4) (4.12.2)

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import re

class WikipediaMovieScraper:
    BASE_URL = "https://en.wikipedia.org"
    
    def __init__(self, list_url):
        self.list_url = list_url
        self.films_data = []
    
    def _get_html(self, url):
        try:
            response = requests.get(url, timeout=10)
            response.raise_for_status()
            return response.text
        except (requests.RequestException, ConnectionError) as e:
            print(f"Error fetching {url}: {e}")
            return None
    
    def _parse_table_rows(self, html):
        soup = BeautifulSoup(html, 'html.parser')
        table = soup.find('table', {'class': 'wikitable'})
        return table.find_all('tr') if table else []
    
    def get_movie_list(self):
        html = self._get_html(self.list_url)
        if not html:
            return []
        return self._parse_table_rows(html)
    
    def _extract_image_url(self, table):
        img_td = table.find('td', class_='infobox-image')
        if not img_td:
            return None
        
        img_tag = img_td.find('img')
        if not img_tag or 'src' not in img_tag.attrs:
            return None
        
        src = img_tag['src']
        if src.startswith('//'):
            src = f'https:{src}'
        return urljoin(self.BASE_URL, src)
    
    def _extract_director(self, data):
        director_links = data.find_all('a')
        if director_links:
            # If there's only one link, check if the text contains concatenated names
            if len(director_links) == 1:
                director_text = director_links[0].get_text(strip=True)
                # Split when a lowercase letter is immediately followed by an uppercase letter
                directors = re.split(r'(?<=[a-z])(?=[A-Z])', director_text)
                return [d.strip() for d in directors if d.strip()]
            else:
                return [link.get_text(strip=True) for link in director_links]
        # Fallback if no <a> tags are found
        director_text = data.get_text(strip=True)
        directors = re.split(r'(?<=[a-z])(?=[A-Z])', director_text)
        return [d.strip() for d in directors if d.strip()]
    
    def _clean_box_office(self, text):
        cleaned = text.replace('\xa0', ' ').replace('\u202f', ' ').strip()
        # Insert space between number and unit if missing
        cleaned = re.sub(
            r'(\d+(?:\.\d+)?)([bm]illion)',
            r'\1 \2',
            cleaned,
            flags=re.IGNORECASE
        )
        return cleaned
    
    def _extract_country(self, data):
        country_elements = data.find_all(['li', 'a'])
        if country_elements:
            return [elem.get_text(strip=True) for elem in country_elements]
        
        text = data.get_text(separator=', ', strip=True)
        text = re.sub(r'(?<!^)(United)(?=\s)', r', \1', text)  # Fix concatenated countries
        return [c.strip() for c in text.split(',') if c.strip()]
    
    def get_movie_details(self, url):
        html = self._get_html(url)
        if not html:
            return {}, None
        
        soup = BeautifulSoup(html, 'html.parser')
        table = soup.find('table', {'class': 'infobox vevent'})
        if not table:
            return {}, None
        
        details = {
            'director': [],
            'box_office': '',
            'country': [],
        }
        
        # Remove reference superscripts first
        for sup in table.find_all("sup"):
            sup.decompose()
        
        for row in table.find_all('tr'):
            header = row.find('th')
            data = row.find('td')
            if not header or not data:
                continue
            
            header_text = header.get_text(strip=True)
            if header_text == "Directed by":
                details['director'] = self._extract_director(data)
            elif header_text == "Box office":
                details['box_office'] = self._clean_box_office(data.get_text(strip=True))
            elif header_text in {"Country", "Country of origin", "Countries"}:
                details['country'] = self._extract_country(data)
        
        return details, self._extract_image_url(table)
    
    def _parse_movie_row(self, row):
        cols = row.find_all(['th', 'td'])
        
        title_col = cols[2]
        year_col = cols[4]
        rank = int(cols[0].get_text(strip=True))
        
        link_tag = title_col.find('a')
        if not link_tag or 'href' not in link_tag.attrs:
            return None
        
        details_url = urljoin(self.BASE_URL, link_tag['href'])
        details, img_url = self.get_movie_details(details_url)
        
        try:
            year_text = year_col.get_text(strip=True)
            release_year = int(re.search(r'\d{4}', year_text).group()) if year_text else None
        except (ValueError, AttributeError):
            release_year = None
        
        return {
            'title': title_col.get_text(strip=True).replace("†", "").strip(),
            'release_year': release_year,
            'director': details['director'],
            'box_office': details['box_office'][details['box_office'].find('$'):],
            'country': details['country'],
            'img_url': img_url,
            'rank': rank
        }
    
    def scrape(self):
        rows = self.get_movie_list()
        for row in rows[1:]:  # Skip header
            film_data = self._parse_movie_row(row)
            if film_data:
                self.films_data.append(film_data)
        return self.films_data


LIST_URL = "https://en.wikipedia.org/wiki/List_of_highest-grossing_films"
scraper = WikipediaMovieScraper(LIST_URL)
films_data = scraper.scrape()
print(f"Scraped {len(films_data)} movies")

films_data
# Out:
# Scraped 50 movies
# [{'title': 'Avatar',
#   'release_year': 2009,
#   'director': ['James Cameron'],
#   'box_office': '$2.923 billion',
#   'country': ['United Kingdom', 'United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/d/d6/Avatar_%282009_film%29_poster.jpg/220px-Avatar_%282009_film%29_poster.jpg',
#   'rank': 1},
#  {'title': 'Avengers: Endgame',
#   'release_year': 2019,
#   'director': ['Anthony Russo', 'Joe Russo'],
#   'box_office': '$2.799 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/0/0d/Avengers_Endgame_poster.jpg',
#   'rank': 2},
#  {'title': 'Avatar: The Way of Water',
#   'release_year': 2022,
#   'director': ['James Cameron'],
#   'box_office': '$2.320 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/5/54/Avatar_The_Way_of_Water_poster.jpg/220px-Avatar_The_Way_of_Water_poster.jpg',
#   'rank': 3},
#  {'title': 'Titanic',
#   'release_year': 1997,
#   'director': ['James Cameron'],
#   'box_office': '$2.264 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/1/18/Titanic_%281997_film%29_poster.png',
#   'rank': 4},
#  {'title': 'Star Wars: The Force Awakens',
#   'release_year': 2015,
#   'director': ['J. J. Abrams'],
#   'box_office': '$2.07 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/a/a2/Star_Wars_The_Force_Awakens_Theatrical_Poster.jpg',
#   'rank': 5},
#  {'title': 'Avengers: Infinity War',
#   'release_year': 2018,
#   'director': ['Anthony Russo', 'Joe Russo'],
#   'box_office': '$2.052 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/4/4d/Avengers_Infinity_War_poster.jpg',
#   'rank': 6},
#  {'title': 'Spider-Man: No Way Home',
#   'release_year': 2021,
#   'director': ['Jon Watts'],
#   'box_office': '$1.953 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/0/00/Spider-Man_No_Way_Home_poster.jpg/220px-Spider-Man_No_Way_Home_poster.jpg',
#   'rank': 7},
#  {'title': 'Ne Zha 2',
#   'release_year': 2025,
#   'director': ['Jiaozi'],
#   'box_office': '$1.84-1.89 billion',
#   'country': ['China'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/b/b6/Ne_Zha_2_poster.jpg/220px-Ne_Zha_2_poster.jpg',
#   'rank': 8},
#  {'title': 'Inside Out 2',
#   'release_year': 2024,
#   'director': ['Kelsey Mann'],
#   'box_office': '$1.699 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/f/f7/Inside_Out_2_poster.jpg/220px-Inside_Out_2_poster.jpg',
#   'rank': 9},
#  {'title': 'Jurassic World',
#   'release_year': 2015,
#   'director': ['Colin Trevorrow'],
#   'box_office': '$1.671 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/6/6e/Jurassic_World_poster.jpg/220px-Jurassic_World_poster.jpg',
#   'rank': 10},
#  {'title': 'The Lion King',
#   'release_year': 2019,
#   'director': ['Jon Favreau'],
#   'box_office': '$1.657 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/9/9d/Disney_The_Lion_King_2019.jpg',
#   'rank': 11},
#  {'title': 'The Avengers',
#   'release_year': 2012,
#   'director': ['Joss Whedon'],
#   'box_office': '$1.521 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/8/8a/The_Avengers_%282012_film%29_poster.jpg',
#   'rank': 12},
#  {'title': 'Furious 7',
#   'release_year': 2015,
#   'director': ['James Wan'],
#   'box_office': '$1.515 billion',
#   'country': ['United States', 'China'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/b/b8/Furious_7_poster.jpg/220px-Furious_7_poster.jpg',
#   'rank': 13},
#  {'title': 'Top Gun: Maverick',
#   'release_year': 2022,
#   'director': ['Joseph Kosinski'],
#   'box_office': '$1.496 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/1/13/Top_Gun_Maverick_Poster.jpg/220px-Top_Gun_Maverick_Poster.jpg',
#   'rank': 14},
#  {'title': 'Frozen 2',
#   'release_year': 2019,
#   'director': ['Chris Buck', 'Jennifer Lee'],
#   'box_office': '$1.453 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/8/89/Frozen_II_%282019_animated_film%29.jpg/220px-Frozen_II_%282019_animated_film%29.jpg',
#   'rank': 15},
#  {'title': 'Barbie',
#   'release_year': 2023,
#   'director': ['Greta Gerwig'],
#   'box_office': '$1.446 billion',
#   'country': ['United States', 'United Kingdom'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/0/0b/Barbie_2023_poster.jpg',
#   'rank': 16},
#  {'title': 'Avengers: Age of Ultron',
#   'release_year': 2015,
#   'director': ['Joss Whedon'],
#   'box_office': '$1.405 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/f/ff/Avengers_Age_of_Ultron_poster.jpg',
#   'rank': 17},
#  {'title': 'The Super Mario Bros. Movie',
#   'release_year': 2023,
#   'director': ['Aaron Horvath', 'Michael Jelenic'],
#   'box_office': '$1.360 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/4/44/The_Super_Mario_Bros._Movie_poster.jpg/220px-The_Super_Mario_Bros._Movie_poster.jpg',
#   'rank': 18},
#  {'title': 'Black Panther',
#   'release_year': 2018,
#   'director': ['Ryan Coogler'],
#   'box_office': '$1.35 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/d/d6/Black_Panther_%28film%29_poster.jpg',
#   'rank': 19},
#  {'title': 'Harry Potter and the Deathly Hallows – Part 2',
#   'release_year': 2011,
#   'director': ['David Yates'],
#   'box_office': '$1.342 billion',
#   'country': ['United Kingdom', 'United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/d/df/Harry_Potter_and_the_Deathly_Hallows_%E2%80%93_Part_2.jpg',
#   'rank': 20},
#  {'title': 'Deadpool & Wolverine',
#   'release_year': 2024,
#   'director': ['Shawn Levy'],
#   'box_office': '$1.338 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/4/4c/Deadpool_%26_Wolverine_poster.jpg/220px-Deadpool_%26_Wolverine_poster.jpg',
#   'rank': 21},
#  {'title': 'Star Wars: The Last Jedi',
#   'release_year': 2017,
#   'director': ['Rian Johnson'],
#   'box_office': '$1.334 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/7/7f/Star_Wars_The_Last_Jedi.jpg',
#   'rank': 22},
#  {'title': 'Jurassic World: Fallen Kingdom',
#   'release_year': 2018,
#   'director': ['J. A. Bayona'],
#   'box_office': '$1.31 billion',
#   'country': ['China', 'United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/c/c6/Jurassic_World_Fallen_Kingdom.png/220px-Jurassic_World_Fallen_Kingdom.png',
#   'rank': 23},
#  {'title': 'Frozen',
#   'release_year': 2013,
#   'director': ['Chris Buck', 'Jennifer Lee'],
#   'box_office': '$1.280 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/0/05/Frozen_%282013_film%29_poster.jpg/220px-Frozen_%282013_film%29_poster.jpg',
#   'rank': 24},
#  {'title': 'Beauty and the Beast',
#   'release_year': 2017,
#   'director': ['Bill Condon'],
#   'box_office': '$1.266 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/d/d6/Beauty_and_the_Beast_2017_poster.jpg',
#   'rank': 25},
#  {'title': 'Incredibles 2',
#   'release_year': 2018,
#   'director': ['Brad Bird'],
#   'box_office': '$1.243 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/1/1f/Incredibles_2_%282018_animated_film%29.jpg/220px-Incredibles_2_%282018_animated_film%29.jpg',
#   'rank': 26},
#  {'title': 'The Fate of the Furious',
#   'release_year': 2017,
#   'director': ['F. Gary Gray'],
#   'box_office': '$1.236 billion',
#   'country': ['United States', 'China'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/2/2d/The_Fate_of_The_Furious_Theatrical_Poster.jpg/220px-The_Fate_of_The_Furious_Theatrical_Poster.jpg',
#   'rank': 27},
#  {'title': 'Iron Man 3',
#   'release_year': 2013,
#   'director': ['Shane Black'],
#   'box_office': '$1.266 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/1/19/Iron_Man_3_poster.jpg',
#   'rank': 28},
#  {'title': 'Minions',
#   'release_year': 2015,
#   'director': ['Pierre Coffin', 'Kyle Balda'],
#   'box_office': '$1.159 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/1/19/Minions_%282015_film%29.jpg',
#   'rank': 29},
#  {'title': 'Captain America: Civil War',
#   'release_year': 2016,
#   'director': ['Anthony Russo', 'Joe Russo'],
#   'box_office': '$1.155 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/5/53/Captain_America_Civil_War_poster.jpg',
#   'rank': 30},
#  {'title': 'Aquaman',
#   'release_year': 2018,
#   'director': ['James Wan'],
#   'box_office': '$1.152 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/e/ed/Aquaman_%28film%29_poster.jpg',
#   'rank': 31},
#  {'title': 'The Lord of the Rings: The Return of the King',
#   'release_year': 2003,
#   'director': ['Peter Jackson'],
#   'box_office': '$1.151 billion',
#   'country': ['New Zealand', 'Germany', 'United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/4/48/Lord_Rings_Return_King.jpg',
#   'rank': 32},
#  {'title': 'Spider-Man: Far From Home',
#   'release_year': 2019,
#   'director': ['Jon Watts'],
#   'box_office': '$1.133 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/b/bd/Spider-Man_Far_From_Home_poster.jpg',
#   'rank': 33},
#  {'title': 'Captain Marvel',
#   'release_year': 2019,
#   'director': ['Anna Boden', 'Ryan Fleck'],
#   'box_office': '$1.131 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/4/4e/Captain_Marvel_%28film%29_poster.jpg',
#   'rank': 34},
#  {'title': 'Transformers: Dark of the Moon',
#   'release_year': 2011,
#   'director': ['Michael Bay'],
#   'box_office': '$1.124 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/b/bf/Transformers_dark_of_the_moon_ver5.jpg/220px-Transformers_dark_of_the_moon_ver5.jpg',
#   'rank': 35},
#  {'title': 'Skyfall',
#   'release_year': 2012,
#   'director': ['Sam Mendes'],
#   'box_office': '$1.109 billion',
#   'country': ['United Kingdom', 'United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/a/a7/Skyfall_poster.jpg/220px-Skyfall_poster.jpg',
#   'rank': 36},
#  {'title': 'Transformers: Age of Extinction',
#   'release_year': 2014,
#   'director': ['Michael Bay'],
#   'box_office': '$1.104 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/0/0f/Transformers_Age_of_Extinction_poster.jpg/220px-Transformers_Age_of_Extinction_poster.jpg',
#   'rank': 37},
#  {'title': 'The Dark Knight Rises',
#   'release_year': 2012,
#   'director': ['Christopher Nolan'],
#   'box_office': '$1.115 billion',
#   'country': ['United States', 'United Kingdom'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/8/83/Dark_knight_rises_poster.jpg',
#   'rank': 38},
#  {'title': 'Joker',
#   'release_year': 2019,
#   'director': ['Todd Phillips'],
#   'box_office': '$1.079 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/e/e1/Joker_%282019_film%29_poster.jpg/220px-Joker_%282019_film%29_poster.jpg',
#   'rank': 39},
#  {'title': 'Star Wars: The Rise of Skywalker',
#   'release_year': 2019,
#   'director': ['J. J. Abrams'],
#   'box_office': '$1.077 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/a/af/Star_Wars_The_Rise_of_Skywalker_poster.jpg',
#   'rank': 40},
#  {'title': 'Toy Story 4',
#   'release_year': 2019,
#   'director': ['Josh Cooley'],
#   'box_office': '$1.074 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/4/4c/Toy_Story_4_poster.jpg',
#   'rank': 41},
#  {'title': 'Toy Story 3',
#   'release_year': 2010,
#   'director': ['Lee Unkrich'],
#   'box_office': '$1.067 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/6/69/Toy_Story_3_poster.jpg',
#   'rank': 42},
#  {'title': "Pirates of the Caribbean: Dead Man's Chest",
#   'release_year': 2006,
#   'director': ['Gore Verbinski'],
#   'box_office': '$1.066 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/2/2d/Pirates_of_the_caribbean_2_poster_b.jpg/220px-Pirates_of_the_caribbean_2_poster_b.jpg',
#   'rank': 43},
#  {'title': 'Rogue One: A Star Wars Story',
#   'release_year': 2016,
#   'director': ['Gareth Edwards'],
#   'box_office': '$1.059 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/d/d4/Rogue_One%2C_A_Star_Wars_Story_poster.png/220px-Rogue_One%2C_A_Star_Wars_Story_poster.png',
#   'rank': 44},
#  {'title': 'Moana 2',
#   'release_year': 2024,
#   'director': ['David Derrick Jr.'],
#   'box_office': '$1.05 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/7/73/Moana_2_poster.jpg/220px-Moana_2_poster.jpg',
#   'rank': 45},
#  {'title': 'Aladdin',
#   'release_year': 2019,
#   'director': ['Guy Ritchie'],
#   'box_office': '$1.054 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/9/9a/Aladdin_%28Official_2019_Film_Poster%29.png',
#   'rank': 46},
#  {'title': 'Star Wars: Episode I – The Phantom Menace',
#   'release_year': 1999,
#   'director': ['George Lucas'],
#   'box_office': '$1.047 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/4/40/Star_Wars_Phantom_Menace_poster.jpg/220px-Star_Wars_Phantom_Menace_poster.jpg',
#   'rank': 47},
#  {'title': 'Pirates of the Caribbean: On Stranger Tides',
#   'release_year': 2011,
#   'director': ['Rob Marshall'],
#   'box_office': '$1.046 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/5/5e/Pirates_of_the_Caribbean_-_On_Stranger_Tides.png/220px-Pirates_of_the_Caribbean_-_On_Stranger_Tides.png',
#   'rank': 48},
#  {'title': 'Jurassic Park',
#   'release_year': 1993,
#   'director': ['Steven Spielberg'],
#   'box_office': '$1.058 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/e/e7/Jurassic_Park_poster.jpg',
#   'rank': 49},
#  {'title': 'Despicable Me 3',
#   'release_year': 2017,
#   'director': ['Pierre Coffin', 'Kyle Balda'],
#   'box_office': '$1.035 billion',
#   'country': ['United States'],
#   'img_url': 'https://upload.wikimedia.org/wikipedia/en/thumb/8/80/Despicable_Me_3_theatrical_release_poster.jpg/220px-Despicable_Me_3_theatrical_release_poster.jpg',
#   'rank': 50}]

# %%
import sqlite3
import json

# Connect to the database (creates films.db if it doesn't exist)
conn = sqlite3.connect('films.db')
cursor = conn.cursor()

# Create the movies table with UNIQUE constraints (if not exists)
cursor.execute('''
    CREATE TABLE IF NOT EXISTS movies (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        title TEXT,
        release_year INTEGER,
        director TEXT,
        box_office TEXT,
        country TEXT,
        img_url TEXT,
        rank INTEGER UNIQUE,
        UNIQUE(title, release_year)
    )
''')

# Insert data into the table using INSERT OR IGNORE to skip duplicates
for film in films_data:
    cursor.execute('''
        INSERT OR IGNORE INTO movies (title, release_year, director, box_office, country, img_url, rank)
        VALUES (?, ?, ?, ?, ?, ?, ?)
    ''', (
        film['title'],
        film['release_year'],
        json.dumps(film['director']),  # Convert list to JSON string
        film['box_office'],
        json.dumps(film['country']),     # Convert list to JSON string
        film['img_url'],
        film['rank']
    ))

conn.commit()

# Optional: Retrieve and print all rows to verify insertion
cursor.execute("SELECT * FROM movies")
rows = cursor.fetchall()
for row in rows:
    print(row)

conn.close()
# Out:
# (1, 'Avatar', 2009, '["James Cameron"]', '$2.923 billion', '["United Kingdom", "United States"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/d/d6/Avatar_%282009_film%29_poster.jpg/220px-Avatar_%282009_film%29_poster.jpg', 1)
# (2, 'Avengers: Endgame', 2019, '["Anthony Russo", "Joe Russo"]', '$2.799 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/0/0d/Avengers_Endgame_poster.jpg', 2)
# (3, 'Avatar: The Way of Water', 2022, '["James Cameron"]', '$2.320 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/5/54/Avatar_The_Way_of_Water_poster.jpg/220px-Avatar_The_Way_of_Water_poster.jpg', 3)
# (4, 'Titanic', 1997, '["James Cameron"]', '$2.264 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/1/18/Titanic_%281997_film%29_poster.png', 4)
# (5, 'Star Wars: The Force Awakens', 2015, '["J. J. Abrams"]', '$2.07 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/a/a2/Star_Wars_The_Force_Awakens_Theatrical_Poster.jpg', 5)
# (6, 'Avengers: Infinity War', 2018, '["Anthony Russo", "Joe Russo"]', '$2.052 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/4/4d/Avengers_Infinity_War_poster.jpg', 6)
# (7, 'Spider-Man: No Way Home', 2021, '["Jon Watts"]', '$1.953 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/0/00/Spider-Man_No_Way_Home_poster.jpg/220px-Spider-Man_No_Way_Home_poster.jpg', 7)
# (8, 'Ne Zha 2', 2025, '["Jiaozi"]', '$1.84-1.89 billion', '["China"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/b/b6/Ne_Zha_2_poster.jpg/220px-Ne_Zha_2_poster.jpg', 8)
# (9, 'Inside Out 2', 2024, '["Kelsey Mann"]', '$1.699 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/f/f7/Inside_Out_2_poster.jpg/220px-Inside_Out_2_poster.jpg', 9)
# (10, 'Jurassic World', 2015, '["Colin Trevorrow"]', '$1.671 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/6/6e/Jurassic_World_poster.jpg/220px-Jurassic_World_poster.jpg', 10)
# (11, 'The Lion King', 2019, '["Jon Favreau"]', '$1.657 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/9/9d/Disney_The_Lion_King_2019.jpg', 11)
# (12, 'The Avengers', 2012, '["Joss Whedon"]', '$1.521 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/8/8a/The_Avengers_%282012_film%29_poster.jpg', 12)
# (13, 'Furious 7', 2015, '["James Wan"]', '$1.515 billion', '["United States", "China"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/b/b8/Furious_7_poster.jpg/220px-Furious_7_poster.jpg', 13)
# (14, 'Top Gun: Maverick', 2022, '["Joseph Kosinski"]', '$1.496 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/1/13/Top_Gun_Maverick_Poster.jpg/220px-Top_Gun_Maverick_Poster.jpg', 14)
# (15, 'Frozen 2', 2019, '["Chris Buck", "Jennifer Lee"]', '$1.453 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/8/89/Frozen_II_%282019_animated_film%29.jpg/220px-Frozen_II_%282019_animated_film%29.jpg', 15)
# (16, 'Barbie', 2023, '["Greta Gerwig"]', '$1.446 billion', '["United States", "United Kingdom"]', 'https://upload.wikimedia.org/wikipedia/en/0/0b/Barbie_2023_poster.jpg', 16)
# (17, 'Avengers: Age of Ultron', 2015, '["Joss Whedon"]', '$1.405 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/f/ff/Avengers_Age_of_Ultron_poster.jpg', 17)
# (18, 'The Super Mario Bros. Movie', 2023, '["Aaron Horvath", "Michael Jelenic"]', '$1.360 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/4/44/The_Super_Mario_Bros._Movie_poster.jpg/220px-The_Super_Mario_Bros._Movie_poster.jpg', 18)
# (19, 'Black Panther', 2018, '["Ryan Coogler"]', '$1.35 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/d/d6/Black_Panther_%28film%29_poster.jpg', 19)
# (20, 'Harry Potter and the Deathly Hallows – Part 2', 2011, '["David Yates"]', '$1.342 billion', '["United Kingdom", "United States"]', 'https://upload.wikimedia.org/wikipedia/en/d/df/Harry_Potter_and_the_Deathly_Hallows_%E2%80%93_Part_2.jpg', 20)
# (21, 'Deadpool & Wolverine', 2024, '["Shawn Levy"]', '$1.338 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/4/4c/Deadpool_%26_Wolverine_poster.jpg/220px-Deadpool_%26_Wolverine_poster.jpg', 21)
# (22, 'Star Wars: The Last Jedi', 2017, '["Rian Johnson"]', '$1.334 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/7/7f/Star_Wars_The_Last_Jedi.jpg', 22)
# (23, 'Jurassic World: Fallen Kingdom', 2018, '["J. A. Bayona"]', '$1.31 billion', '["China", "United States"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/c/c6/Jurassic_World_Fallen_Kingdom.png/220px-Jurassic_World_Fallen_Kingdom.png', 23)
# (24, 'Frozen', 2013, '["Chris Buck", "Jennifer Lee"]', '$1.280 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/0/05/Frozen_%282013_film%29_poster.jpg/220px-Frozen_%282013_film%29_poster.jpg', 24)
# (25, 'Beauty and the Beast', 2017, '["Bill Condon"]', '$1.266 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/d/d6/Beauty_and_the_Beast_2017_poster.jpg', 25)
# (26, 'Incredibles 2', 2018, '["Brad Bird"]', '$1.243 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/1/1f/Incredibles_2_%282018_animated_film%29.jpg/220px-Incredibles_2_%282018_animated_film%29.jpg', 26)
# (27, 'The Fate of the Furious', 2017, '["F. Gary Gray"]', '$1.236 billion', '["United States", "China"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/2/2d/The_Fate_of_The_Furious_Theatrical_Poster.jpg/220px-The_Fate_of_The_Furious_Theatrical_Poster.jpg', 27)
# (28, 'Iron Man 3', 2013, '["Shane Black"]', '$1.266 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/1/19/Iron_Man_3_poster.jpg', 28)
# (29, 'Minions', 2015, '["Pierre Coffin", "Kyle Balda"]', '$1.159 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/1/19/Minions_%282015_film%29.jpg', 29)
# (30, 'Captain America: Civil War', 2016, '["Anthony Russo", "Joe Russo"]', '$1.155 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/5/53/Captain_America_Civil_War_poster.jpg', 30)
# (31, 'Aquaman', 2018, '["James Wan"]', '$1.152 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/e/ed/Aquaman_%28film%29_poster.jpg', 31)
# (32, 'The Lord of the Rings: The Return of the King', 2003, '["Peter Jackson"]', '$1.151 billion', '["New Zealand", "Germany", "United States"]', 'https://upload.wikimedia.org/wikipedia/en/4/48/Lord_Rings_Return_King.jpg', 32)
# (33, 'Spider-Man: Far From Home', 2019, '["Jon Watts"]', '$1.133 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/b/bd/Spider-Man_Far_From_Home_poster.jpg', 33)
# (34, 'Captain Marvel', 2019, '["Anna Boden", "Ryan Fleck"]', '$1.131 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/4/4e/Captain_Marvel_%28film%29_poster.jpg', 34)
# (35, 'Transformers: Dark of the Moon', 2011, '["Michael Bay"]', '$1.124 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/b/bf/Transformers_dark_of_the_moon_ver5.jpg/220px-Transformers_dark_of_the_moon_ver5.jpg', 35)
# (36, 'Skyfall', 2012, '["Sam Mendes"]', '$1.109 billion', '["United Kingdom", "United States"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/a/a7/Skyfall_poster.jpg/220px-Skyfall_poster.jpg', 36)
# (37, 'Transformers: Age of Extinction', 2014, '["Michael Bay"]', '$1.104 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/0/0f/Transformers_Age_of_Extinction_poster.jpg/220px-Transformers_Age_of_Extinction_poster.jpg', 37)
# (38, 'The Dark Knight Rises', 2012, '["Christopher Nolan"]', '$1.115 billion', '["United States", "United Kingdom"]', 'https://upload.wikimedia.org/wikipedia/en/8/83/Dark_knight_rises_poster.jpg', 38)
# (39, 'Joker', 2019, '["Todd Phillips"]', '$1.079 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/e/e1/Joker_%282019_film%29_poster.jpg/220px-Joker_%282019_film%29_poster.jpg', 39)
# (40, 'Star Wars: The Rise of Skywalker', 2019, '["J. J. Abrams"]', '$1.077 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/a/af/Star_Wars_The_Rise_of_Skywalker_poster.jpg', 40)
# (41, 'Toy Story 4', 2019, '["Josh Cooley"]', '$1.074 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/4/4c/Toy_Story_4_poster.jpg', 41)
# (42, 'Toy Story 3', 2010, '["Lee Unkrich"]', '$1.067 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/6/69/Toy_Story_3_poster.jpg', 42)
# (43, "Pirates of the Caribbean: Dead Man's Chest", 2006, '["Gore Verbinski"]', '$1.066 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/2/2d/Pirates_of_the_caribbean_2_poster_b.jpg/220px-Pirates_of_the_caribbean_2_poster_b.jpg', 43)
# (44, 'Rogue One: A Star Wars Story', 2016, '["Gareth Edwards"]', '$1.059 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/d/d4/Rogue_One%2C_A_Star_Wars_Story_poster.png/220px-Rogue_One%2C_A_Star_Wars_Story_poster.png', 44)
# (45, 'Moana 2', 2024, '["David Derrick Jr."]', '$1.05 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/7/73/Moana_2_poster.jpg/220px-Moana_2_poster.jpg', 45)
# (46, 'Aladdin', 2019, '["Guy Ritchie"]', '$1.054 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/9/9a/Aladdin_%28Official_2019_Film_Poster%29.png', 46)
# (47, 'Star Wars: Episode I – The Phantom Menace', 1999, '["George Lucas"]', '$1.047 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/4/40/Star_Wars_Phantom_Menace_poster.jpg/220px-Star_Wars_Phantom_Menace_poster.jpg', 47)
# (48, 'Pirates of the Caribbean: On Stranger Tides', 2011, '["Rob Marshall"]', '$1.046 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/5/5e/Pirates_of_the_Caribbean_-_On_Stranger_Tides.png/220px-Pirates_of_the_Caribbean_-_On_Stranger_Tides.png', 48)
# (49, 'Jurassic Park', 1993, '["Steven Spielberg"]', '$1.058 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/e/e7/Jurassic_Park_poster.jpg', 49)
# (50, 'Despicable Me 3', 2017, '["Pierre Coffin", "Kyle Balda"]', '$1.035 billion', '["United States"]', 'https://upload.wikimedia.org/wikipedia/en/thumb/8/80/Despicable_Me_3_theatrical_release_poster.jpg/220px-Despicable_Me_3_theatrical_release_poster.jpg', 50)

# %%
import sqlite3
import json

def export_to_json(db_path, json_file_path):
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()
    
    # Retrieve all rows from the movies table
    cursor.execute("SELECT * FROM movies")
    rows = cursor.fetchall()
    
    films = []
    for row in rows:
        film = {
            "id": row[0],
            "title": row[1],
            "release_year": row[2],
            # Stored as JSON strings in the DB; convert them back to lists
            "director": json.loads(row[3]),
            "box_office": row[4],
            "country": json.loads(row[5]),
            "img_url": row[6],
            "rank": row[7]
        }
        films.append(film)
    
    conn.close()
    
    # Write the list of films to a JSON file with indentation for readability
    with open(json_file_path, 'w') as f:
        json.dump(films, f, indent=4)
    
    print(f"Database content exported to {json_file_path}")

export_to_json('films.db', 'films_data.json')
# Out:
# Database content exported to films_data.json
